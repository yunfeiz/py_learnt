# %%
import pyhkconnect as hkc
dp = hkc.northbound_shareholding_sh() # dataframe from pandas
dp
# Out:
#       code                                               name   shareholding  \
# 0    90000  SHANGHAI PUDONG DEVELOPMENT BANK CO., LTD. (A ...    432,600,632
# 1    90004  GUANGZHOU BAIYUN INTERNATIONAL AIRPORT CO.,LTD...    190,058,444
# 2    90006            DONGFENG AUTOMOBILE CO.,LTD (A #600006)      1,360,220
# 3    90007  CHINA WORLD TRADE CENTER COMPANY LTD. (A #600007)     15,656,599
# 4    90008                BEIJING CAPITAL CO.,LTD (A #600008)     84,561,617
# 5    90009  SHANGHAI INTERNATIONAL AIRPORT CO., LTD. (A #6...    325,095,003
# 6    90010  INNER MONGOLIA BAOTOU STEEL UNION CO.,LTD. (A ...    258,585,949
# 7    90011      HUANENG POWER INTERNATIONAL, INC. (A #600011)     51,752,802
# 8    90012       ANHUI EXPRESSWAY COMPANY LIMITED (A #600012)      7,759,992
# 9    90015              HUA XIA BANK CO., LIMITED (A #600015)     99,421,652
# 10   90016     CHINA MINSHENG BANKING CORP., LTD. (A #600016)    615,082,700
# ...

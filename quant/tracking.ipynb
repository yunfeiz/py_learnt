# %%
# %run get_big_order.py  -v 400 -t 0  -i all.txt
# Out:
# ...
# Sorting by Abs Ascending:
# ...
#         Code   Name            Buy           Sell           Abs
# 1849  600887   伊利股份  133230.529047   80773.361605  52457.167442
# 287   000401   冀东水泥  102896.900238   66106.506221  36790.394017
# 143   000725   京东方Ａ   95667.466457   61576.581668  34090.884789
# 260   000983   西山煤电  105120.007661   71176.755392  33943.252269
# 1522  000600   建投能源   66629.791972   39080.448520  27549.343452
# 1273  601225   陕西煤业  103239.723798   76348.593101  26891.130697
# 1211  000970   中科三环  101130.881359   74240.682678  26890.198681
# 520   600111   北方稀土  185147.182079  160033.033681  25114.148398
# 457   000858  五 粮 液   51223.227918   28821.320065  22401.907853
# 577   000937   冀中能源   58747.540357   37299.831492  21447.708865
# 1104  601699   潞安环能   93802.954327   72453.573034  21349.381293
# 1925  601600   中国铝业  188476.660891  169584.301245  18892.359646
# 1140  300070    碧水源   59414.486260   40807.761584  18606.724676
# ...

# %%
# %run  show_price.py
# Out:
# Can't open the file
# ...
#       Code   Price Pre_close    High     Low  Percentage     Range    Average     Amount      Time
# 5   002230  45.770    45.630  46.570  45.050    0.003068  0.033740  45.944986  13.097663  13:37:12
# 17  600435  15.210    15.540  15.480  15.050   -0.021236  0.028571  15.234158   7.953734  13:37:10
# 1   600487  26.910    26.330  27.060  26.120    0.022028  0.035988  26.773754   3.559601  13:37:10
# 3   000413  10.910    10.890  10.960  10.780    0.001837  0.016698  10.902651   3.184525  13:37:12
# 16  300078  12.700    12.570  13.140  12.480    0.010342  0.052885  12.803276   2.946783  13:37:12
# 8   000839   9.600     9.580   9.700   9.490    0.002088  0.022129   9.598966   2.492797  13:37:12
# 9   300024  20.060    19.780  20.270  19.730    0.014156  0.027369  20.093421   2.427548  13:37:12
# 11  002074  34.010    33.510  34.330  33.430    0.014921  0.026922  33.955898   2.393842  13:37:09
# ...

# %%
# %run show_big_order.py  -v 1000 -t 0  -s 002167
# Out:
# timed out
#         time     volume
# 0   09:30:03  1210200.0
# 1   09:30:45  -162750.0
# 2   09:30:51  -186600.0
# 3   09:31:06   175000.0
# 4   09:31:15  -187100.0
# 5   09:31:24   217100.0
# 6   09:31:42  -172300.0
# 7   09:31:57   314700.0
# 8   09:32:03  -166600.0
# 9   09:32:15  -214900.0
# 10  09:32:27   219300.0
# 11  09:34:21  -182200.0
# 12  09:35:48   116500.0
# 13  09:38:57   107900.0
# 14  09:39:24   301600.0
# 15  09:39:51   219800.0
# 16  09:40:33   208200.0
# 17  09:41:30  -149900.0
# 18  09:41:45   105000.0
# 19  09:41:48  -112400.0
# 20  09:42:54   267950.0
# 21  09:48:45  -239400.0
# 22  09:49:00   110500.0
# 23  09:51:15  -147100.0
# 24  09:55:33   107700.0
# 25  09:57:00   123900.0
# 26  09:57:42  -154800.0
# 27  10:00:36  -100700.0
# 28  10:11:09  -190750.0
# 29  10:11:51  -304500.0
# 30  10:15:06  -206000.0
# 31  10:16:48   105800.0
# 32  10:40:03  -104500.0
# 33  10:48:39  -108300.0
# 34  11:00:12   111500.0
# 35  13:16:24   221100.0
# 36  13:17:06   211600.0
# ...
